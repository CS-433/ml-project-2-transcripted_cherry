# %%
import numpy as np
import time, os, sys, random
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

import statsmodels.api as sm
from scipy import stats

# %%
df = pd.read_excel(r"C:\Users\alexi\EPFL\MA3\Machine_learning\20151218_E14_BM_mTF8additionals_4\features_cells_A1.xlsx")

# %%
df = df[df['patch_size']>50]
df = df[df['patch_size']<4000]

# %%
df.reset_index(inplace = True)
df.drop('sum_intensity', inplace = True,axis = 1)
df['mean_intensity2'] = df.mean_intensity**2
df['median_intensity2'] = df.median_intensity**2
df['mean_intensity3'] = df.mean_intensity**3
df['median_intensity3'] = df.median_intensity**3
df.head()
# Out:
#    index Unnamed: 0  patch_size  mean_intensity  median_intensity  img  \
# 0      2    patch_1        1209      973.141439             974.0    0
# 1      3    patch_2        1181      959.066046             959.0    0
# 2      4    patch_3        2544      919.231132             918.0    0
# 3      5    patch_4        1598     1036.212140            1037.0    0
# 4      6    patch_5         473      861.281184             860.0    0
#
#    mean_intensity2  median_intensity2  mean_intensity3  median_intensity3
# 0     9.470043e+05           948676.0     9.215691e+08       9.240104e+08
# 1     9.198077e+05           919681.0     8.821563e+08       8.819741e+08
# 2     8.449859e+05           842724.0     7.767373e+08       7.736206e+08
# 3     1.073736e+06          1075369.0     1.112618e+09       1.115158e+09
# 4     7.418053e+05           739600.0     6.389029e+08       6.360560e+08

# %%
for i in range(12):
    X = df.to_numpy()[:,[3,4,6,7,8,9]][df['img']==i]
    Y = df.to_numpy()[:,2][df['img']==i]

    reg = LinearRegression().fit(X, Y)
    print(reg.score(X, Y))
    print(reg.coef_)
    print(reg.intercept_)

for i in range(12):    
    X = df[df.columns[[3,6]]][df['img']==i]
    Y = df['patch_size'][df['img']==i]
    X2 = sm.add_constant(X)
    est = sm.OLS(Y, X2)
    est2 = est.fit()
    print("value/p value for the mean coef and image          ",i," ",round(est2.params[1],5),"//",round(est2.pvalues[1],5))
    print("value/p value for the mean squarred coef and image ",i," ",round(est2.params[2],5),"//",round(est2.pvalues[2],5))
# Out:
# 0.0381784851078919
# [ 7.42652089e+01 -6.38199766e+01 -4.62918040e-02  3.86849332e-02
#   9.77960722e-06 -8.03094248e-06]
# -3663.58336621083
# 0.004687074712997119
# [-4.44401668e+01  4.04174144e+01  3.45806271e-02 -3.13870895e-02
#  -9.06577760e-06  8.19882994e-06]
# 2779.183388721535
# 0.011525037131280613
# [ 5.91605026e+01 -5.64954080e+01 -3.84668557e-02  3.60514136e-02
#   7.55293355e-06 -6.93428200e-06]
# 185.53488058627818
# 0.02105655519645233
# [-1.58726911e+01  1.75188361e+01  1.40872140e-02 -1.59616518e-02
#  -4.53110109e-06  5.01278611e-06]
# 829.5528395276408
# 0.014787098419462907
# [ 1.56711240e+01 -1.52107799e+01 -9.02131677e-03  8.80866465e-03
#   1.51999497e-06 -1.48171352e-06]
# 699.668796163628
# 0.013136277557103448
# [ 1.00362425e+01 -7.26230223e+00 -6.37115177e-03  4.81075759e-03
#   9.85851940e-07 -7.43820453e-07]
# -468.29604841866035
# 0.02450543588495324
# [ 4.10220185e+01 -3.40587104e+01 -2.92025808e-02  2.44070940e-02
#   5.63730499e-06 -4.64352684e-06]
# -2210.826886103434
# 0.017796442392180034
# [ 2.81803027e+01 -2.22942046e+01 -1.70499742e-02  1.27810940e-02
#   3.04860339e-06 -2.12412272e-06]
# -1578.5951966792964
# 0.003366274231226263
# [ 3.23882655e+00 -1.47806251e+00 -2.30743338e-03  1.14589786e-03
#   3.18103833e-07 -1.00606442e-07]
# 179.4869625225674
# 0.006401598679715126
# [ 5.56259464e+01 -4.87055040e+01 -4.05374925e-02  3.47359894e-02
#   8.65582665e-06 -7.13795817e-06]
# -1597.3217028581278
# 0.020067784297826963
# [ 5.57066224e+01 -3.97720226e+01 -4.81468619e-02  3.62176759e-02
#   1.17514000e-05 -8.93417071e-06]
# -5686.411666606731
# 0.00789250988474699
# [-2.54529367e+01  2.28518284e+01  9.36685834e-03 -7.30080757e-03
#   1.21761770e-06 -1.75127210e-06]
# 2308.6776356415608
# value/p value for the mean coef and image           0   0.43859 // 0.13738
# value/p value for the mean squarred coef and image  0   -0.00014 // 0.14944
# value/p value for the mean coef and image           1   -0.35038 // 0.46985
# value/p value for the mean squarred coef and image  1   7e-05 // 0.72141
# value/p value for the mean coef and image           2   -0.72984 // 0.10073
# value/p value for the mean squarred coef and image  2   0.00019 // 0.24598
# value/p value for the mean coef and image           3   -0.14815 // 0.91973
# value/p value for the mean squarred coef and image  3   -0.00024 // 0.71157
# value/p value for the mean coef and image           4   -0.12558 // 0.40652
# value/p value for the mean squarred coef and image  4   7e-05 // 0.0974
# value/p value for the mean coef and image           5   0.64985 // 0.02435
# value/p value for the mean squarred coef and image  5   -0.0002 // 0.01222
# value/p value for the mean coef and image           6   0.82951 // 0.0287
# value/p value for the mean squarred coef and image  6   -0.00032 // 0.0151
# value/p value for the mean coef and image           7   0.43927 // 0.42735
# value/p value for the mean squarred coef and image  7   -0.00026 // 0.19693
# value/p value for the mean coef and image           8   -0.06603 // 0.72709
# value/p value for the mean squarred coef and image  8   1e-05 // 0.8119
# value/p value for the mean coef and image           9   -0.09 // 0.76757
# value/p value for the mean squarred coef and image  9   -0.0 // 0.96685
# value/p value for the mean coef and image           10   1.45444 // 0.01475
# value/p value for the mean squarred coef and image  10   -0.00056 // 0.01954
# value/p value for the mean coef and image           11   0.54737 // 0.43269
# value/p value for the mean squarred coef and image  11   -0.0003 // 0.24777

# %%
plt.figure()
im = 4
plt.plot(df['patch_size'][df['img']==im],df['mean_intensity'][df['img']==im],marker = '.',lw = 0,color = 'red',label = "image "+str(im))
im = 0
plt.plot(df['patch_size'][df['img']==im],df['mean_intensity'][df['img']==im],marker = '.',lw = 0,color = 'black',label = "image "+str(im))
plt.xlabel("patch size")
plt.ylabel("mean intensity")
plt.legend()
plt.show()
